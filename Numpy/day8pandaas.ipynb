# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'Color' : ['Red', 'Blue', 'Green', 'Blue', 'Red', 'Green', 'Red']
})

# %%
df
# Out:
#    Color
# 0    Red
# 1   Blue
# 2  Green
# 3   Blue
# 4    Red
# 5  Green
# 6    Red

# %%
df.dtypes
# Out:
# Color    object
# dtype: object

# %%
df['Color'] = df['Color'].astype('category')

# %%
df
# Out:
#    Color
# 0    Red
# 1   Blue
# 2  Green
# 3   Blue
# 4    Red
# 5  Green
# 6    Red

# %%
df.dtypes
# Out:
# Color    category
# dtype: object

# %%
sizes = pd.Categorical(['s', 'm', 'l', 's', 'm', 'l'], categories=['s', 'm', 'l'], ordered=True)
sizes
# Out:
# ['s', 'm', 'l', 's', 'm', 'l']
# Categories (3, object): ['s' < 'm' < 'l']

# %%
df_grades = pd.DataFrame({'Grades': ['A', 'B', 'C', 'A', 'B', 'C', 'A']})

# %%
df_grades
# Out:
#   Grades
# 0      A
# 1      B
# 2      C
# 3      A
# 4      B
# 5      C
# 6      A

# %%
df_grades.value_counts()
# Out:
# Grades
# A         3
# B         2
# C         2
# Name: count, dtype: int64

# %%
df_grades['Grades'] = df_grades['Grades'].astype('category')

# %%
df_grades.dtypes
# Out:
# Grades    category
# dtype: object

# %%
df = pd.DataFrame({
    'size' : ['S', 'M', 'L', 'M', 'L', 'S' , 'M'],
    'Items' : ['Shirts' , 'Pants' , 'Jackets' , 'Shoes' , 'Hats' , 'Socks' , 'Ties']
})

df
# Out:
#   size    Items
# 0    S   Shirts
# 1    M    Pants
# 2    L  Jackets
# 3    M    Shoes
# 4    L     Hats
# 5    S    Socks
# 6    M     Ties

# %%
df['size'] = pd.Categorical(df['size'], categories=['S', 'M', 'L'], ordered=True)

# %%
df.sort_values(by = 'size')
# Out:
#   size    Items
# 2    L  Jackets
# 4    L     Hats
# 1    M    Pants
# 3    M    Shoes
# 6    M     Ties
# 0    S   Shirts
# 5    S    Socks

# %%
df['size'] > 'M'
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# Name: size, dtype: bool

# %%
df[df['size'] > 'M']
# Out:
#   size   Items
# 0    S  Shirts
# 5    S   Socks

# %%
df[df['size']=='M']
# Out:
#   size  Items
# 1    M  Pants
# 3    M  Shoes
# 6    M   Ties

# %%
df['is_Large'] = df['size'] == 'L'

# %%
df
# Out:
#   size    Items  is_Large
# 0    S   Shirts     False
# 1    M    Pants     False
# 2    L  Jackets      True
# 3    M    Shoes     False
# 4    L     Hats      True
# 5    S    Socks     False
# 6    M     Ties     False

# %%
df[df['size']>'M']
# Out:
#   size   Items  is_Large
# 0    S  Shirts     False
# 5    S   Socks     False

# %%
df[df['size']<'S']
# Out:
#   size    Items  is_Large
# 1    M    Pants     False
# 2    L  Jackets      True
# 3    M    Shoes     False
# 4    L     Hats      True
# 6    M     Ties     False

# %%
df[df['size'] == 'S']
# Out:
#   size   Items  is_Large
# 0    S  Shirts     False
# 5    S   Socks     False
